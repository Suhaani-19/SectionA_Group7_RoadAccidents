# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Load Dataset

# %%
df = pd.read_csv('/content/RTA Dataset.csv')

# %% [markdown]
# ### Basic Dataset Overview

# %%
print("Shape of dataset:", df.shape)
print("\nColumns:\n", df.columns.tolist())
# Out:
# Shape of dataset: (12316, 32)
#
# Columns:
#  ['Time', 'Day_of_week', 'Age_band_of_driver', 'Sex_of_driver', 'Educational_level', 'Vehicle_driver_relation', 'Driving_experience', 'Type_of_vehicle', 'Owner_of_vehicle', 'Service_year_of_vehicle', 'Defect_of_vehicle', 'Area_accident_occured', 'Lanes_or_Medians', 'Road_allignment', 'Types_of_Junction', 'Road_surface_type', 'Road_surface_conditions', 'Light_conditions', 'Weather_conditions', 'Type_of_collision', 'Number_of_vehicles_involved', 'Number_of_casualties', 'Vehicle_movement', 'Casualty_class', 'Sex_of_casualty', 'Age_band_of_casualty', 'Casualty_severity', 'Work_of_casuality', 'Fitness_of_casuality', 'Pedestrian_movement', 'Cause_of_accident', 'Accident_severity']

# %% [markdown]
# ### Preview Data

# %%
df.head()
# Out:
#        Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0  17:02:00      Monday              18-30          Male   Above high school
# 1  17:02:00      Monday              31-50          Male  Junior high school
# 2  17:02:00      Monday              18-30          Male  Junior high school
# 3   1:06:00      Sunday              18-30          Male  Junior high school
# 4   1:06:00      Sunday              18-30          Male  Junior high school
#
#   Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# 0                Employee              1-2yr           Automobile
# 1                Employee         Above 10yr  Public (> 45 seats)
# 2                Employee              1-2yr      Lorry (41?100Q)
# 3                Employee             5-10yr  Public (> 45 seats)
# 4                Employee              2-5yr                  NaN
#
#   Owner_of_vehicle Service_year_of_vehicle  ... Vehicle_movement  \
# 0            Owner              Above 10yr  ...   Going straight
# 1            Owner                 5-10yrs  ...   Going straight
# 2            Owner                     NaN  ...   Going straight
# 3     Governmental                     NaN  ...   Going straight
# 4            Owner                 5-10yrs  ...   Going straight
#
#     Casualty_class Sex_of_casualty Age_band_of_casualty Casualty_severity  \
# 0               na              na                   na                na
# 1               na              na                   na                na
# 2  Driver or rider            Male                31-50                 3
# 3       Pedestrian          Female                18-30                 3
# 4               na              na                   na                na
#
#   Work_of_casuality Fitness_of_casuality Pedestrian_movement  \
# 0               NaN                  NaN    Not a Pedestrian
# 1               NaN                  NaN    Not a Pedestrian
# 2            Driver                  NaN    Not a Pedestrian
# 3            Driver               Normal    Not a Pedestrian
# 4               NaN                  NaN    Not a Pedestrian
#
#             Cause_of_accident Accident_severity
# 0             Moving Backward     Slight Injury
# 1                  Overtaking     Slight Injury
# 2   Changing lane to the left    Serious Injury
# 3  Changing lane to the right     Slight Injury
# 4                  Overtaking     Slight Injury
#
# [5 rows x 32 columns]

# %%
df.sample(10)
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 7123   13:00:00    Thursday              18-30          Male
# 4208    7:49:00    Thursday              18-30          Male
# 617    18:13:00     Tuesday              31-50          Male
# 4808    9:42:00      Friday              18-30          Male
# 8970   17:44:00      Friday           Under 18          Male
# 80     18:48:00   Wednesday              31-50          Male
# 11874  17:10:00   Wednesday              18-30          Male
# 4941   14:04:00    Thursday           Under 18          Male
# 615    18:56:00      Monday            Unknown        Female
# 5304   19:00:00      Sunday              31-50          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 7123   Junior high school                Employee              2-5yr
# 4208                  NaN                     NaN                NaN
# 617    Junior high school                Employee             5-10yr
# 4808    Elementary school                   Owner         Above 10yr
# 8970                  NaN                     NaN                NaN
# 80     Junior high school                Employee              1-2yr
# 11874                 NaN                     NaN                NaN
# 4941          High school                   Owner         Above 10yr
# 615    Junior high school                Employee              2-5yr
# 5304   Junior high school                Employee          Below 1yr
#
#             Type_of_vehicle Owner_of_vehicle Service_year_of_vehicle  ...  \
# 7123                    NaN            Owner                 Unknown  ...
# 4208        Lorry (41?100Q)            Owner                   1-2yr  ...
# 617                   Turbo            Owner                  2-5yrs  ...
# 4808       Pick up upto 10Q              NaN                     NaN  ...
# 8970   Public (13?45 seats)            Owner                  2-5yrs  ...
# 80           Lorry (11?40Q)            Owner                 Unknown  ...
# 11874            Automobile            Owner              Above 10yr  ...
# 4941             Automobile            Owner                 Unknown  ...
# 615          Lorry (11?40Q)            Owner                  2-5yrs  ...
# 5304             Automobile            Owner                     NaN  ...
#
#       Vehicle_movement   Casualty_class Sex_of_casualty Age_band_of_casualty  \
# 7123    Going straight               na              na                   na
# 4208             Other               na              na                   na
# 617           Turnover               na              na                   na
# 4808    Going straight               na              na                   na
# 8970    Going straight  Driver or rider            Male                18-30
# 80      Going straight  Driver or rider          Female                31-50
# 11874   Going straight  Driver or rider            Male                18-30
# 4941    Going straight        Passenger            Male                18-30
# 615     Going straight  Driver or rider            Male              Over 51
# 5304   Moving Backward  Driver or rider            Male              Over 51
#
#       Casualty_severity Work_of_casuality Fitness_of_casuality  \
# 7123                 na            Driver               Normal
# 4208                 na     Self-employed               Normal
# 617                  na               NaN                  NaN
# 4808                 na            Driver               Normal
# 8970                  3            Driver               Normal
# 80                    3             Other               Normal
# 11874                 3            Driver               Normal
# 4941                  3            Driver               Normal
# 615                   3               NaN                  NaN
# 5304                  3            Driver               Normal
#
#       Pedestrian_movement          Cause_of_accident Accident_severity
# 7123     Not a Pedestrian                 Overtaking     Slight Injury
# 4208     Not a Pedestrian                 Overtaking    Serious Injury
# 617      Not a Pedestrian            Moving Backward    Serious Injury
# 4808     Not a Pedestrian  No priority to pedestrian     Slight Injury
# 8970     Not a Pedestrian  Changing lane to the left     Slight Injury
# 80       Not a Pedestrian  Changing lane to the left    Serious Injury
# 11874    Not a Pedestrian  Changing lane to the left     Slight Injury
# 4941     Not a Pedestrian                      Other     Slight Injury
# 615      Not a Pedestrian  Changing lane to the left     Slight Injury
# 5304     Not a Pedestrian              No distancing     Slight Injury
#
# [10 rows x 32 columns]

# %% [markdown]
# ### Dataset Information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12316 entries, 0 to 12315
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         12316 non-null  object
#  1   Day_of_week                  12316 non-null  object
#  2   Age_band_of_driver           12316 non-null  object
#  3   Sex_of_driver                12316 non-null  object
#  4   Educational_level            11575 non-null  object
#  5   Vehicle_driver_relation      11737 non-null  object
#  6   Driving_experience           11487 non-null  object
#  7   Type_of_vehicle              11366 non-null  object
#  8   Owner_of_vehicle             11834 non-null  object
#  9   Service_year_of_vehicle      8388 non-null   object
#  10  Defect_of_vehicle            7889 non-null   object
#  11  Area_accident_occured        12077 non-null  object
#  12  Lanes_or_Medians             11931 non-null  object
#  13  Road_allignment              12174 non-null  object
#  14  Types_of_Junction            11429 non-null  object
#  15  Road_surface_type            12144 non-null  object
#  16  Road_surface_conditions      12316 non-null  object
#  17  Light_conditions             12316 non-null  object
#  18  Weather_conditions           12316 non-null  object
#  19  Type_of_collision            12161 non-null  object
#  20  Number_of_vehicles_involved  12316 non-null  int64
#  21  Number_of_casualties         12316 non-null  int64
#  22  Vehicle_movement             12008 non-null  object
#  23  Casualty_class               12316 non-null  object
#  24  Sex_of_casualty              12316 non-null  object
#  25  Age_band_of_casualty         12316 non-null  object
#  26  Casualty_severity            12316 non-null  object
#  27  Work_of_casuality            9118 non-null   object
#  28  Fitness_of_casuality         9681 non-null   object
#  29  Pedestrian_movement          12316 non-null  object
#  30  Cause_of_accident            12316 non-null  object
#  31  Accident_severity            12316 non-null  object
# dtypes: int64(2), object(30)
# memory usage: 3.0+ MB

# %% [markdown]
# ### Understand categorical values

# %%
for col in df.select_dtypes(include='object'):
    print(col, df[col].nunique())
# Out:
# Time 1074
# Day_of_week 7
# Age_band_of_driver 5
# Sex_of_driver 3
# Educational_level 7
# Vehicle_driver_relation 4
# Driving_experience 7
# Type_of_vehicle 17
# Owner_of_vehicle 4
# Service_year_of_vehicle 6
# Defect_of_vehicle 3
# Area_accident_occured 14
# Lanes_or_Medians 7
# Road_allignment 9
# Types_of_Junction 8
# Road_surface_type 5
# Road_surface_conditions 4
# Light_conditions 4
# Weather_conditions 9
# Type_of_collision 10
# Vehicle_movement 13
# Casualty_class 4
# Sex_of_casualty 3
# Age_band_of_casualty 6
# Casualty_severity 4
# Work_of_casuality 7
# Fitness_of_casuality 5
# Pedestrian_movement 9
# Cause_of_accident 20
# Accident_severity 3

# %% [markdown]
# ### Check for Missing Values (only seeing)

# %%
df.isnull().sum()
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level               741
# Vehicle_driver_relation         579
# Driving_experience              829
# Type_of_vehicle                 950
# Owner_of_vehicle                482
# Service_year_of_vehicle        3928
# Defect_of_vehicle              4427
# Area_accident_occured           239
# Lanes_or_Medians                385
# Road_allignment                 142
# Types_of_Junction               887
# Road_surface_type               172
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Type_of_collision               155
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                308
# Casualty_class                    0
# Sex_of_casualty                   0
# Age_band_of_casualty              0
# Casualty_severity                 0
# Work_of_casuality              3198
# Fitness_of_casuality           2635
# Pedestrian_movement               0
# Cause_of_accident                 0
# Accident_severity                 0
# dtype: int64

# %% [markdown]
# ### Check for Duplicate Rows

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Basic Statistical Summary

# %%
df.describe()
# Out:
#        Number_of_vehicles_involved  Number_of_casualties
# count                 12316.000000          12316.000000
# mean                      2.040679              1.548149
# std                       0.688790              1.007179
# min                       1.000000              1.000000
# 25%                       2.000000              1.000000
# 50%                       2.000000              1.000000
# 75%                       2.000000              2.000000
# max                       7.000000              8.000000
